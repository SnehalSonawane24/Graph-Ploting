# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('Iris3.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Line Graph Plot

# %%
plt.plot(df.Id,df.PetalLengthCm)
plt.show()

# %% [markdown]
# # Bar Graph Plot

# %%
plt.bar(df.Id,df.PetalLengthCm, color='g')
plt.show()

# %% [markdown]
# # Pie Chart

# %%
plt.pie(df.PetalLengthCm)
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(df.Id,df.PetalLengthCm)

# %% [markdown]
# # Box Chart

# %%
plt.boxplot(df.PetalLengthCm)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x246461bc3a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x246461bc940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x246461bc0d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x246461bcee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x246461bd1b0>],
#  'means': []}
